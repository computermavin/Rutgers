# %%
# Author Mavin
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
from math import sqrt
import scipy
import matplotlib.pyplot as plt
#Estimators
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import linear_model

#model metrics

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#cross validation
from sklearn.cross_validation import train_test_split

rawData = pd.read_csv('defaultofcreditcardclients_o.csv', header =1)
rawData.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#features
features=rawData.iloc[:,12:23]
print('Summary of feature sample head')
features.head()
# Out:
# Summary of feature sample head
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 2      29239      14027      13559      14331      14948      15549      1518
# 3      46990      48233      49291      28314      28959      29547      2000
# 4       8617       5670      35835      20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 2      1500      1000      1000      1000
# 3      2019      1200      1100      1069
# 4     36681     10000      9000       689

# %%
#dependent variable
depVar = rawData['PAY_AMT6']

# %%
#Training Set ( Feature space : X Training)
X_train = (features[:1000])
X_train.head()
# Out:
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 2      29239      14027      13559      14331      14948      15549      1518
# 3      46990      48233      49291      28314      28959      29547      2000
# 4       8617       5670      35835      20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 2      1500      1000      1000      1000
# 3      2019      1200      1100      1069
# 4     36681     10000      9000       689

# %%
#Dependent Variable Training Set (y Training)
y_train = depVar[: 1000]
y_train_count = len(y_train.index)
print('The number of observations in the Y training set are:',str(y_train_count))
y_train.head()
# Out:
# The number of observations in the Y training set are: 1000
# 0       0
# 1    2000
# 2    5000
# 3    1000
# 4     679
# Name: PAY_AMT6, dtype: int64

# %%
#testing set (x testing)
X_test = features[-100:]
X_test_count = len(X_test.index)
print ('Number of observations in feature testing set are : ' , str(X_test_count))
print(X_test.head())
X_test.head()
# Out:
# Number of observations in feature testing set are :  100
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 29900      16809          0          0          0          0          0
# 29901      50845      48750     103486      50590      50248      49387
# 29902      10392     168088     168955     161351     126198     124746
# 29903      27378      17082      13333         99         99     172104
# 29904      54952      56021      54126      58732      59306      59728
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 29900         0         0         0         0         0
# 29901         0      6556      3250      1563      1208
# 29902    168096      6409      7335      4448      4519
# 29903     10018     13333        99        99    172104
# 29904      2600      4553      5800      2000      1000
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
#Ground Truth (y_test)
y_test = depVar[:-100]
y_test_count = len(y_test.index)
print('The number of observations in the training set are: ', str(y_test_count))
y_test.head()
# Out:
# The number of observations in the training set are:  29900
# 0       0
# 1    2000
# 2    5000
# 3    1000
# 4     679
# Name: PAY_AMT6, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train)

# %%
X_train.shape, X_test.shape
# Out:
# ((750, 11), (250, 11))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train)
X_train.shape, X_test.shape
# Out:
# ((562, 11), (188, 11))

# %%
#Models
modelSVR = SVR()
modelRF = RandomForestRegressor()
modelLR = LinearRegression()

# %%
features.head()
# Out:
#    BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0       3913       3102        689          0          0          0         0
# 1       2682       1725       2682       3272       3455       3261         0
# 2      29239      14027      13559      14331      14948      15549      1518
# 3      46990      48233      49291      28314      28959      29547      2000
# 4       8617       5670      35835      20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5
# 0       689         0         0         0
# 1      1000      1000      1000         0
# 2      1500      1000      1000      1000
# 3      2019      1200      1100      1069
# 4     36681     10000      9000       689

# %%
print(depVar)
# Out:
# 0            0
# 1         2000
# 2         5000
# 3         1000
# 4          679
# 5          800
# 6        13770
# 7         1542
# 8         1000
# 9            0
# 10          66
# 11        3640
# 12           0
# 13           0
# 14        3000
# 15        1100
# 16           0
# 17       50000
# 18           0
# 19           0
# 20       33764
# 21           0
# 22        1820
# 23        1128
# 24        2000
# 25         997
# 26        1000
# 27        1012
# 28           0
# 29           0
#          ...
# 29970    16080
# 29971     3000
# 29972     4800
# 29973        0
# 29974     1000
# 29975     7022
# 29976        0
# 29977     5000
# 29978    10059
# 29979        0
# 29980     2000
# 29981      585
# 29982        0
# 29983     1701
# 29984     1000
# 29985        0
# 29986        0
# 29987     4005
# 29988     6009
# 29989        0
# 29990     2000
# 29991        0
# 29992        0
# 29993     2000
# 29994     4000
# 29995     1000
# 29996        0
# ...

# %%
#Random Forest
modelRF.fit(X_train,y_train)
print(cross_val_score(modelRF, X_train, y_train))
modelRF.score(X_train,y_train)
# Out:
# [ 0.01021123  0.04057545 -0.00485183]
# 0.820029299488569

# %%
#SVR
modelSVR.fit(X_train,y_train)
print(cross_val_score(modelSVR, X_train, y_train)) 
modelSVR.score(X_train,y_train)
# Out:
# [-0.05179626 -0.01153832 -0.0544919 ]
# -0.018719104547322285

# %%
modelLR.fit(X_train,y_train)
print(cross_val_score(modelLR, X_train, y_train)) 
modelLR.score(X_train,y_train)
# Out:
# [-0.78022485  0.02264642 -1.02353395]
# 0.554467013405097

# %%
## Choosing Random forest which had highest score of0.82 (SVR was negative and Liner regression was 0,5544)
predictions = modelRF.predict(X_test)
predRsquared = r2_score(y_test,predictions)
rmse = sqrt(mean_squared_error(y_test, predictions))
print('R Squared: %.3f' % predRsquared)
print('RMSE: %.3f' % rmse)
# Out:
# R Squared: -0.055
# RMSE: 26368.864

# %%
plt.scatter(y_test, predictions, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();
